# %% [markdown]
# <a href="https://colab.research.google.com/github/KaishvaShah/EE610_ImageProcessing/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
from google.colab.patches import cv2_imshow
img = cv2.imread('/tree.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=640x398 at 0x7FF931674E50>

# %%
#source - https://pixabay.com/photos/tree-sunset-clouds-sky-silhouette-736885/

# %%
print(img.shape)
# Out:
# (398, 640, 3)

# %% [markdown]
# The image has resolution 398 x 640 i.e. 398 rows, 640 columns. The three represents the number of layers used. Here 3 because one for each Red, BLue, Green.

# %%
print(img[0]) #represents all the pixels in the first row with their intensities in RBG respectivels
# Out:
# [[24  9 17]
#  [24  9 17]
#  [25  9 20]
#  ...
#  [31 13 14]
#  [31 13 14]
#  [31 13 14]]

# %%
print(img[:120, :120])
 #these represent the intensities of the pixels in the top left of the image. its of size 120 x 120
# Out:
# [[[24  9 17]
#   [24  9 17]
#   [25  9 20]
#   ...
#   [26 11  8]
#   [25 12  4]
#   [23 11  0]]
#
#  [[25 10 18]
#   [25 10 18]
#   [25 10 18]
#   ...
#   [29 14 12]
#   [28 13 10]
#   [28 15  7]]
#
#  [[26 12 18]
#   [25 11 17]
#   [24 10 16]
#   ...
#   [28 11 15]
#   [26  9 12]
#   [26 10 11]]
#
#  ...
#
#  [[40 17 22]
#   [40 17 22]
#   [40 17 22]
#   ...
#   [57 23 64]
#   [56 22 62]
#   [55 22 59]]
#
#  [[42 18 26]
#   [41 17 25]
#   [41 17 25]
#   ...
#   [56 25 62]
#   [56 26 61]
#   [55 26 59]]
#
#  [[43 19 27]
#   [42 18 26]
#   [42 18 26]
#   ...
#   [58 28 63]
#   [58 29 62]
#   [57 29 58]]]

# %%
cv2_imshow(img[:120, :120])
# Out:
# <PIL.Image.Image image mode=RGB size=120x120 at 0x7FF931752910>

# %% [markdown]
# The origin of the image is at the top left of the image

# %%
for i in range(120):
  for j in range(120):
    img1[i,j]=[255,255,255]
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=640x398 at 0x7FF9317526D0>

# %% [markdown]
# As we can observe, the top left has been intensified to become completely white. This is because we set the values of the pixels in that area to be 255, in all 3 layers, which is the maximum intensity.

# %%
for i in range(120):
  for j in range(120):
    img[i,j]=[256,256,256]

# %% [markdown]
# When we set the pixel values to be 256 it overflows and becomes 0 which makes it look black. This can be observed above.

# %%
img1 = img[20:370, 20:620]
cv2_imshow(img1)
print(img1.shape)
# Out:
# <PIL.Image.Image image mode=RGB size=600x350 at 0x7FF931674690>
# (350, 600, 3)

# %% [markdown]
# As you can see, the cropped image of size 350 x 600 x 3 has been created from the original image of size 398 x 640 x 3.

# %%
cv2.imwrite('/img1.png',img1) #saved the image as img1
# Out:
# True

# %%
cv2_imshow(img + 50)
# Out:
# <PIL.Image.Image image mode=RGB size=640x398 at 0x7FF943E130D0>

# %% [markdown]
# This is what it would have looked like if we added 50 to each pixel value for our image.

# %%
cv2_imshow(cv2.flip(img,1))
# Out:
# <PIL.Image.Image image mode=RGB size=640x398 at 0x7FF927DC6F10>

# %% [markdown]
# Clearly as image has been flipped we can notice the deintensified pixels on the top right.
